# %%
from utils import preprocess_text, get_feature_probabilities

# %%
groups = dict()
actr_dict = dict()
groups['actr'] = {"Act1": "Introducing the new Cornell Block", "Act2": "introducing cornell", "Act3": "cornell cornell introducing"}

# %%
groups
# Out:
# {'actr': {'Act1': 'Introducing the new Cornell Block',
#   'Act2': 'introducing cornell',
#   'Act3': 'cornell cornell introducing'}}

# %%
feature_probs, all_matrices = get_feature_probabilities(groups)
# Out:
# Processing occupations: 100%|██████████| 1/1 [00:00<00:00, 448.06it/s]

# %%
feature_probs
# Out:
# defaultdict(dict,
#             {'actr': {'cornell': 1.0,
#               'introducing': 1.0,
#               'new': 0.3333333333333333,
#               'block': 0.3333333333333333}})

# %%
all_matrices
# Out:
# {'actr': {'features': ['cornell', 'introducing', 'new', 'block'],
#   'matrix': array([[0.33333333, 0.33333333, 0.        , 0.33333333],
#          [0.5       , 0.        , 0.25      , 0.25      ],
#          [0.5       , 0.        , 0.        , 0.5       ],
#          [0.        , 0.        , 0.        , 0.        ]])}}

# %%
from utils import plot_heatmap
plot_heatmap(all_matrices['actr'], 'actr')
